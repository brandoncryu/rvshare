# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./rvshare.csv')
df['length']=df['length'].str.replace('ft','').astype(float)
df['price_nightly']=df['price_nightly'].str.replace('$','').str.replace(',','').astype(int)
df
# df.corr()
# Out:
#                         bathroom cancellation                       distance  \
# 0    Shower,Toilet,Bathroom Sink     Standard   2.6 miles from San Diego, CA
# 1    Shower,Toilet,Bathroom Sink     Standard  14.2 miles from San Diego, CA
# 2    Shower,Toilet,Bathroom Sink     Standard  14.2 miles from San Diego, CA
# 3    Shower,Bathroom Sink,Toilet     Standard  11.7 miles from San Diego, CA
# 4    Shower,Toilet,Bathroom Sink     Standard   8.3 miles from San Diego, CA
# ..                           ...          ...                            ...
# 120  Shower,Toilet,Bathroom Sink     Flexible    14.8 miles from Seattle, WA
# 121  Shower,Toilet,Bathroom Sink     Standard     5.0 miles from Seattle, WA
# 122  Shower,Toilet,Bathroom Sink     Standard    12.2 miles from Seattle, WA
# 123  Shower,Toilet,Bathroom Sink     Standard    15.6 miles from Seattle, WA
# 124  Shower,Bathroom Sink,Toilet     Standard    19.0 miles from Seattle, WA
#
# ...

# %%
df.plot(x='length', y='price', kind='scatter')

# %%
df.plot(x='year', y='price', kind='scatter')
